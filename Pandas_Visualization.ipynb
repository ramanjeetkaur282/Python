# %% [markdown]
# # Pandas Visualization

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/Users/ramanjeetkaur/Documents/Data Analytics/Pandas/Ice Cream Ratings.csv')

# %%
df=df.set_index('Date')
df
# Out:
#           Flavor Rating  Texture Rating  Overall Rating
# Date
# 1/1/2022       0.223090        0.040220        0.600129
# 1/2/2022       0.635886        0.938476        0.106264
# 1/3/2022       0.442323        0.044154        0.598112
# 1/4/2022       0.389128        0.549676        0.489353
# 1/5/2022       0.386887        0.519439        0.988280
# 1/6/2022       0.877984        0.193588        0.832827
# 1/7/2022       0.140995        0.325110        0.105147

# %%
df=df.set_index('Date')
df
# Out:
#           Flavor Rating  Texture Rating  Overall Rating
# Date
# 1/1/2022       0.223090        0.040220        0.600129
# 1/2/2022       0.635886        0.938476        0.106264
# 1/3/2022       0.442323        0.044154        0.598112
# 1/4/2022       0.389128        0.549676        0.489353
# 1/5/2022       0.386887        0.519439        0.988280
# 1/6/2022       0.877984        0.193588        0.832827
# 1/7/2022       0.140995        0.325110        0.105147

# %%
df=df.set_index('Date')
df
# Out:
#           Flavor Rating  Texture Rating  Overall Rating
# Date
# 1/1/2022       0.223090        0.040220        0.600129
# 1/2/2022       0.635886        0.938476        0.106264
# 1/3/2022       0.442323        0.044154        0.598112
# 1/4/2022       0.389128        0.549676        0.489353
# 1/5/2022       0.386887        0.519439        0.988280
# 1/6/2022       0.877984        0.193588        0.832827
# 1/7/2022       0.140995        0.325110        0.105147

# %%
df=df.set_index('Date')
df
# Out:
#           Flavor Rating  Texture Rating  Overall Rating
# Date
# 1/1/2022       0.223090        0.040220        0.600129
# 1/2/2022       0.635886        0.938476        0.106264
# 1/3/2022       0.442323        0.044154        0.598112
# 1/4/2022       0.389128        0.549676        0.489353
# 1/5/2022       0.386887        0.519439        0.988280
# 1/6/2022       0.877984        0.193588        0.832827
# 1/7/2022       0.140995        0.325110        0.105147

# %%
df.plot(kind = 'line',title='Ice cream Ratings',xlabel='Daily Ratings',ylabel='ratings')
# Out:
# <Axes: title={'center': 'Ice cream Ratings'}, xlabel='Daily Ratings', ylabel='ratings'>

# %%
df.plot(kind = 'bar',subplots=True,title='Ice cream Ratings',xlabel='Daily Ratings',ylabel='ratings')
# Out:
# array([<Axes: title={'center': 'Flavor Rating'}, xlabel='Daily Ratings', ylabel='ratings'>,
#        <Axes: title={'center': 'Texture Rating'}, xlabel='Daily Ratings', ylabel='ratings'>,
#        <Axes: title={'center': 'Overall Rating'}, xlabel='Daily Ratings', ylabel='ratings'>],
#       dtype=object)

# %%
df.plot(kind = 'bar',subplots=True,title='Ice cream Ratings',xlabel='Daily Ratings',ylabel='ratings')
# Out:
# array([<Axes: title={'center': 'Flavor Rating'}, xlabel='Daily Ratings', ylabel='ratings'>,
#        <Axes: title={'center': 'Texture Rating'}, xlabel='Daily Ratings', ylabel='ratings'>,
#        <Axes: title={'center': 'Overall Rating'}, xlabel='Daily Ratings', ylabel='ratings'>],
#       dtype=object)

# %%
df['Flavor Rating'].plot(kind='bar',stacked=True)
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot.barh(stacked=True)
# Out:
# <Axes: ylabel='Date'>

# %%
df.plot.scatter(x='Texture Rating',y='Overall Rating', s=500,c='Red')
# Out:
# <Axes: xlabel='Texture Rating', ylabel='Overall Rating'>

# %%
df.plot.hist(bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
df.plot.area(figsize=(10,5,))
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot.pie(y='Flavor Rating',figsize=(30,10))
# Out:
# <Axes: ylabel='Flavor Rating'>
